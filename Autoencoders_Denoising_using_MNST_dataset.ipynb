# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Sequential

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, _), (x_test, _) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))

# %%
#adding some nosie
noise_factor =0.5
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape)

# %%
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
#Display images with noise
plt.figure(figsize=(20, 2))
for i in range(1,10):
    ax = plt,plt.subplot(1, 10, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap="binary")
plt.show()

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2), padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D((2, 2),padding='same'))
model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))


model.add(MaxPooling2D((2, 2), padding='same'))

model.add(Conv2D(8, (3, 3), activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(8, (3, 3),activation='relu', padding='same'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(UpSampling2D((2, 2)))
model.add(Conv2D(1, (3, 3), activation='relu', padding='same'))



model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()

model.fit(x_train_noisy, x_train, epochs=10, batch_size=256, shuffle=True,
          validation_data=(x_test_noisy, x_test))


model.evaluate(x_test_noisy, x_test)

model.save('denoising_autoencoder.model')

no_noise_img = model.predict(x_test_noisy)

plt.figure(figsize=(40, 4))
for i in range(10):
    #display original
    ax = plt.subplot(3, 20, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap="binary")

    #display reconstructed (after noise removed) image
    ax = plt.subplot(3, 20, 40 +i+1)
    plt.imshow(no_noise_img[i].reshape(28, 28), cmap="binary")

plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_42 (Conv2D)          (None, 28, 28, 32)        320
#
#  max_pooling2d_20 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 14, 14, 8)         2312
#
#  max_pooling2d_21 (MaxPoolin  (None, 7, 7, 8)          0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 7, 7, 8)           584
#
#  max_pooling2d_22 (MaxPoolin  (None, 4, 4, 8)          0
#  g2D)
#
#  conv2d_45 (Conv2D)          (None, 4, 4, 8)           584
#
#  up_sampling2d_15 (UpSamplin  (None, 8, 8, 8)          0
#  g2D)
#
#  conv2d_46 (Conv2D)          (None, 8, 8, 8)           584
#
#  up_sampling2d_16 (UpSamplin  (None, 16, 16, 8)        0
#  g2D)
#
#  conv2d_47 (Conv2D)          (None, 14, 14, 32)        2336
#
#  up_sampling2d_17 (UpSamplin  (None, 28, 28, 32)       0
#  g2D)
#
#  conv2d_48 (Conv2D)          (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 7,009
# Trainable params: 7,009
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 235/235 [==============================] - 125s 526ms/step - loss: 0.0530 - val_loss: 0.0391
# Epoch 2/10
# 235/235 [==============================] - 128s 543ms/step - loss: 0.0363 - val_loss: 0.0337
# Epoch 3/10
# 235/235 [==============================] - 125s 534ms/step - loss: 0.0326 - val_loss: 0.0309
# Epoch 4/10
# 235/235 [==============================] - 125s 533ms/step - loss: 0.0302 - val_loss: 0.0288
# Epoch 5/10
# 235/235 [==============================] - 124s 528ms/step - loss: 0.0285 - val_loss: 0.0275
# Epoch 6/10
# 235/235 [==============================] - 125s 533ms/step - loss: 0.0272 - val_loss: 0.0266
# Epoch 7/10
# 235/235 [==============================] - 125s 533ms/step - loss: 0.0262 - val_loss: 0.0255
# Epoch 8/10
# 235/235 [==============================] - 127s 541ms/step - loss: 0.0254 - val_loss: 0.0246
# Epoch 9/10
# 235/235 [==============================] - 125s 532ms/step - loss: 0.0247 - val_loss: 0.0242
# Epoch 10/10
# 235/235 [==============================] - 124s 530ms/step - loss: 0.0240 - val_loss: 0.0233
# 313/313 [==============================] - 5s 17ms/step - loss: 0.0233
# INFO:tensorflow:Assets written to: denoising_autoencoder.model/assets
